# %% [markdown]
# # Sending Emails using Python

# %% [markdown]
# # Requirements:

# %% [markdown]
# SMTP:
# - Simple Mail Transfer Protocol(or SMTP) is the protocol used for sending e-mail over the Internet.
# - When an email is sent, it's transferred over the internet from one server to another server and finally reaches to the destination using SMTP.
# - For this project, we are going to use Gmail SMTP severe. So create a Gmail account from which the mail has to been sent.

# %% [markdown]
# ![SMTP-IMAP-1.png](attachment:SMTP-IMAP-1.png)

# %% [markdown]
# Emails library:
# - Install emails library from https://pypi.org/project/emails/
# - This library is used to get functions for sending an email.

# %% [markdown]
# # Email Sending process:

# %% [markdown]
# ### Problem statement:
# - A Python Script which we can use to send emails to our friends and family members
# ___
#
# ### Steps:
# - The first step is to import emails package.
#     - Import emails
#
# - Now the required message is converted to HTML.For this, you can go to this website https://wordtohtml.net/ for converting normal text to HTML tags. And pass the text in this function. And also pass the subject and mail name.
#     - **message = emails.html(html = html_text,**
#     - **subject="Your EMAIL FROM PYTHON SCRIPT",**
#     - **mail_from=('sender name', 'mail@xyz.com'))**
#
# - Finally, send the email using send() give the to address. And also specify the from mail id and its password.
#     - **mail_via_python = message.send(to='nabipi7212@econeom.com',**
#     - **smtp={'host': 'smtp.gmail.com','timeout': 5,'port':587,**
#     - **'user':'YOUREMAIL@REQUIRED>COM',**
#     - **'password':'YourPassWordRequired',**
# 	- **'tls':True})**
#
#         - Here is the detail of the parameters:
#              - **host** − This is the host running your SMTP server. You can specify IP address of the host or a domain name
#               like xyz.com. This is optional argument.
#              - **port** − If you are providing host argument, then you need to specify a port, where SMTP server is  listening. Usually this port would be 25.
#              - **local_hostname** − If your SMTP server is running on your local machine, then you can specify just localhost as of this option.
# ___
#
# - An SMTP object has an instance method called sendmail, which is typically used to do the work of mailing a message. It takes three parameters:
#    - **The sender** − A string with the address of the sender.
#    - **The receivers** − A list of strings, one for each recipient.
#    - **The message** − A message as a string formatted as specified in the various RFCs.

# %% [markdown]
# ### Sending an HTML e-mail using Python:
# - When you send a text message using Python, then all the content are treated as simple text.
# - Even if you include HTML tags in a text message, it is displayed as simple text and HTML tags will not be formatted according to HTML syntax. But Python provides option to send an HTML message as actual HTML message.
# - While sending an e-mail message, you can specify a Mime version, content type and character set to send an HTML e-mail.

# %% [markdown]
# ### Sending Attachments as an E-mail:
# - To send an e-mail with mixed content requires to set Content-type header to multipart/mixed. Then, text and attachment sections can be specified within boundaries.
# - A boundary is started with two hyphens followed by a unique number, which cannot appear in the message part of the e-mail. A final boundary denoting the e-mail's final section must also end with two hyphens.
# - Attached files should be encoded with the pack("m") function to have base64 encoding before transmission.

# %% [markdown]
# ![email%20sending.jpg](attachment:email%20sending.jpg)
